# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(
	temperature=0.1,
	model="gpt-4o",
	streaming=True,
	callbacks=[
		StreamingStdOutCallbackHandler()
	]
)

chef_prompt = ChatPromptTemplate.from_messages([
	("system", "You are a world-class international chef. You acreate easy to follow receipies for any type of cuisine with easy to find ingredients."),
	("human", "I want to cook {cuisine} food."),
])

chef_chain = chef_prompt | chat

veg_chef_prompt = ChatPromptTemplate.from_messages([
	("system", "You are a vegetarian chef specialized on making traditional recipes vegetarian. You find alternative ingredients and explain their preparation. You don't radically modify the recipe. If there is no alternative for a food just say you don't know how to recipe it."),
	("human", "{recipe}"),
])

veg_chain = veg_chef_prompt | chat

final_chain = chef_chain | veg_chain

final_chain.invoke({
	"cuisine" : "Korean"
})
# Out:
# Great choice! Korean cuisine is full of bold flavors and vibrant dishes. Here's a simple recipe for a classic Korean dish: **Bibimbap**. It's a mixed rice dish topped with vegetables, protein, and a spicy sauce.
#
# ### Bibimbap Recipe
#
# #### Ingredients:
# - 2 cups cooked white rice (short-grain or medium-grain)
# - 1 cup spinach, blanched and squeezed dry
# - 1 cup bean sprouts, blanched
# - 1 medium carrot, julienned
# - 1 zucchini, julienned
# - 4 shiitake mushrooms, sliced
# - 1/2 pound ground beef or sliced beef (like ribeye)
# - 2 eggs
# - 2 tablespoons soy sauce
# - 1 tablespoon sesame oil
# - 1 tablespoon vegetable oil
# - 1 tablespoon sugar
# - 1 tablespoon minced garlic
# - Salt and pepper to taste
# - Sesame seeds for garnish
#
# #### For the Gochujang Sauce:
# - 2 tablespoons gochujang (Korean red pepper paste)
# - 1 tablespoon sesame oil
# - 1 tablespoon sugar
# - 1 tablespoon water
# - 1 teaspoon vinegar
# - 1 teaspoon minced garlic
#
# #### Instructions:
#
# 1. **Prepare the Vegetables:**
#    - Heat a little vegetable oil in a pan over medium heat. Sauté the carrots until tender, about 2-3 minutes. Season with a pinch of salt. Remove and set aside.
#    - In the same pan, sauté the zucchini until tender, about 2-3 minutes. Season with a pinch of salt. Remove and set aside.
#    - Sauté the shiitake mushrooms with a little soy sauce and sesame oil until cooked, about 3-4 minutes. Remove and set aside.
#
# 2. **Cook the Beef:**
#    - In the same pan, add the ground beef or sliced beef. Cook until browned. Add 2 tablespoons soy sauce, 1 tablespoon sugar, and 1 tablespoon minced garlic. Cook until the beef is fully cooked and the sauce is absorbed. Set aside.
#
# 3. **Fry the Eggs:**
#    - In a clean pan, fry the eggs sunny-side up or to your preference.
#
# 4. **Make the Gochujang Sauce:**
#    - In a small bowl, mix together the gochujang, sesame oil, sugar, water, vinegar, and minced garlic until smooth.
#
# 5. **Assemble the Bibimbap:**
#    - In a large bowl, place a serving of cooked rice at the bottom.
#    - Arrange the spinach, bean sprouts, carrots, zucchini, mushrooms, and beef around the edges of the bowl.
#    - Place the fried egg on top of the rice.
#    - Drizzle with the gochujang sauce and sprinkle with sesame seeds.
#
# 6. **Serve:**
#    - Mix everything together before eating to combine the flavors. Enjoy your homemade Bibimbap!
#
# Feel free to customize the toppings based on your preference or what you have on hand. You can add kimchi, other vegetables, or even tofu for a vegetarian version. Enjoy your cooking adventure!To make this classic Korean Bibimbap vegetarian, we can easily substitute the beef with a plant-based protein and ensure the rest of the ingredients are vegetarian-friendly. Here's how you can do it:
#
# ### Vegetarian Bibimbap Recipe
#
# #### Ingredients:
# - 2 cups cooked white rice (short-grain or medium-grain)
# - 1 cup spinach, blanched and squeezed dry
# - 1 cup bean sprouts, blanched
# - 1 medium carrot, julienned
# - 1 zucchini, julienned
# - 4 shiitake mushrooms, sliced
# - 1/2 pound firm tofu or tempeh, crumbled or sliced
# - 2 eggs (optional, or use a vegan egg substitute)
# - 2 tablespoons soy sauce
# - 1 tablespoon sesame oil
# - 1 tablespoon vegetable oil
# - 1 tablespoon sugar
# - 1 tablespoon minced garlic
# - Salt and pepper to taste
# - Sesame seeds for garnish
#
# #### For the Gochujang Sauce:
# - 2 tablespoons gochujang (ensure it's vegetarian, as some may contain fish products)
# - 1 tablespoon sesame oil
# - 1 tablespoon sugar
# - 1 tablespoon water
# - 1 teaspoon vinegar
# - 1 teaspoon minced garlic
#
# #### Instructions:
#
# 1. **Prepare the Vegetables:**
#    - Heat a little vegetable oil in a pan over medium heat. Sauté the carrots until tender, about 2-3 minutes. Season with a pinch of salt. Remove and set aside.
#    - In the same pan, sauté the zucchini until tender, about 2-3 minutes. Season with a pinch of salt. Remove and set aside.
#    - Sauté the shiitake mushrooms with a little soy sauce and sesame oil until cooked, about 3-4 minutes. Remove and set aside.
#
# 2. **Cook the Tofu/Tempeh:**
#    - In the same pan, add the crumbled tofu or sliced tempeh. Cook until golden brown. Add 2 tablespoons soy sauce, 1 tablespoon sugar, and 1 tablespoon minced garlic. Cook until the tofu/tempeh is well-coated and the sauce is absorbed. Set aside.
#
# 3. **Fry the Eggs (Optional):**
#    - In a clean pan, fry the eggs sunny-side up or to your preference. Alternatively, prepare a vegan egg substitute according to package instructions.
#
# 4. **Make the Gochujang Sauce:**
#    - In a small bowl, mix together the gochujang, sesame oil, sugar, water, vinegar, and minced garlic until smooth.
#
# 5. **Assemble the Bibimbap:**
#    - In a large bowl, place a serving of cooked rice at the bottom.
#    - Arrange the spinach, bean sprouts, carrots, zucchini, mushrooms, and tofu/tempeh around the edges of the bowl.
#    - Place the fried egg or vegan egg substitute on top of the rice.
#    - Drizzle with the gochujang sauce and sprinkle with sesame seeds.
#
# 6. **Serve:**
#    - Mix everything together before eating to combine the flavors. Enjoy your vegetarian Bibimbap!
#
# Feel free to add other vegetables or toppings like kimchi (ensure it's vegetarian) or avocado for extra flavor and texture. Enjoy your cooking adventure!
# AIMessage(content="To make this classic Korean Bibimbap vegetarian, we can easily substitute the beef with a plant-based protein and ensure the rest of the ingredients are vegetarian-friendly. Here's how you can do it:\n\n### Vegetarian Bibimbap Recipe\n\n#### Ingredients:\n- 2 cups cooked white rice (short-grain or medium-grain)\n- 1 cup spinach, blanched and squeezed dry\n- 1 cup bean sprouts, blanched\n- 1 medium carrot, julienned\n- 1 zucchini, julienned\n- 4 shiitake mushrooms, sliced\n- 1/2 pound firm tofu or tempeh, crumbled or sliced\n- 2 eggs (optional, or use a vegan egg substitute)\n- 2 tablespoons soy sauce\n- 1 tablespoon sesame oil\n- 1 tablespoon vegetable oil\n- 1 tablespoon sugar\n- 1 tablespoon minced garlic\n- Salt and pepper to taste\n- Sesame seeds for garnish\n\n#### For the Gochujang Sauce:\n- 2 tablespoons gochujang (ensure it's vegetarian, as some may contain fish products)\n- 1 tablespoon sesame oil\n- 1 tablespoon sugar\n- 1 tablespoon water\n- 1 teaspoon vinegar\n- 1 teaspoon minced garlic\n\n#### Instructions:\n\n1. **Prepare the Vegetables:**\n   - Heat a little vegetable oil in a pan over medium heat. Sauté the carrots until tender, about 2-3 minutes. Season with a pinch of salt. Remove and set aside.\n   - In the same pan, sauté the zucchini until tender, about 2-3 minutes. Season with a pinch of salt. Remove and set aside.\n   - Sauté the shiitake mushrooms with a little soy sauce and sesame oil until cooked, about 3-4 minutes. Remove and set aside.\n\n2. **Cook the Tofu/Tempeh:**\n   - In the same pan, add the crumbled tofu or sliced tempeh. Cook until golden brown. Add 2 tablespoons soy sauce, 1 tablespoon sugar, and 1 tablespoon minced garlic. Cook until the tofu/tempeh is well-coated and the sauce is absorbed. Set aside.\n\n3. **Fry the Eggs (Optional):**\n   - In a clean pan, fry the eggs sunny-side up or to your preference. Alternatively, prepare a vegan egg substitute according to package instructions.\n\n4. **Make the Gochujang Sauce:**\n   - In a small bowl, mix together the gochujang, sesame oil, sugar, water, vinegar, and minced garlic until smooth.\n\n5. **Assemble the Bibimbap:**\n   - In a large bowl, place a serving of cooked rice at the bottom.\n   - Arrange the spinach, bean sprouts, carrots, zucchini, mushrooms, and tofu/tempeh around the edges of the bowl.\n   - Place the fried egg or vegan egg substitute on top of the rice.\n   - Drizzle with the gochujang sauce and sprinkle with sesame seeds.\n\n6. **Serve:**\n   - Mix everything together before eating to combine the flavors. Enjoy your vegetarian Bibimbap!\n\nFeel free to add other vegetables or toppings like kimchi (ensure it's vegetarian) or avocado for extra flavor and texture. Enjoy your cooking adventure!", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_de57b65c90'}, id='run-a178cbb9-fc55-414f-906e-de27d087022e-0')
